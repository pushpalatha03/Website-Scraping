# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
# Function to extract Product Title
def get_title(soup):

    try:
        title = soup.find("span", attrs={"id":'productTitle'})
        
        title_value = title.text

        title_string = title_value.strip()

    except AttributeError:
        title_string = ""

    return title_string

def get_price(soup):

    try:
        price = soup.find("span", attrs={'class':'a-offscreen'}).string.strip()

    except AttributeError:

        try:
            
            price = soup.find("span", attrs={'id':'a-span12'}).string.strip()

        except:
            price = ""

    return price

def get_rating(soup):

    try:
        rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip()
    
    except AttributeError:
        try:
            rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
        except:
            rating = ""	

    return rating

# Function to extract Number of User Reviews
def get_review_count(soup):
    try:
        review_count = soup.find("span", attrs={'id':'acrCustomerReviewText'}).string.strip()

    except AttributeError:
        review_count = ""	

    return review_count

def get_availability(soup):
    try:
        available = soup.find("div", attrs={'id':'availability'})
        available = available.find("span").string.strip()

    except AttributeError:
        available = "Not Available"	

    return available
if __name__ == '__main__':

    # add your user agent 
    HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36', 'Accept-Language': 'en-US, en;q=0.5'})

    # The webpage URL
    URL = "https://www.amazon.com/s?k=Indian+Flag&crid=2Z4O4OM17BU8S&sprefix=indian+flag%2Caps%2C305&ref=nb_sb_noss_1"

    webpage = requests.get(URL, headers=HEADERS)

    soup = BeautifulSoup(webpage.content, "html.parser")

    links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})

    links_list = []

    for link in links:
            links_list.append(link.get('href'))

    d = {"title":[], "price":[], "rating":[], "reviews":[],"availability":[]}
    
    for link in links_list:
        new_webpage = requests.get("https://www.amazon.com" + link, headers=HEADERS)

        new_soup = BeautifulSoup(new_webpage.content, "html.parser")

        # Function calls to display all necessary product information
        d['title'].append(get_title(new_soup))
        d['price'].append(get_price(new_soup))
        d['rating'].append(get_rating(new_soup))
        d['reviews'].append(get_review_count(new_soup))
        d['availability'].append(get_availability(new_soup))
   
    amazon_df = pd.DataFrame.from_dict(d)
    amazon_df['title'].replace('', np.nan, inplace=True)
    amazon_df = amazon_df.dropna(subset=['title'])
    amazon_df.to_csv("amazon_data.csv", header=True, index=False)

# %%
amazon_df
# Out:
#                                                 title price  \
# 0   Double Sided India Flag 3x5ft Heavy Duty Delux...
# 1   G128 India Indian Flag | 3x5 Ft | LiteWeave Pr...
# 2   Premium USA Indian Flag 3X5Ft Large New, Both ...
# 3   G128 Indiana State Flag | 4x6 Ft | ToughWeave ...
# 4   Anley Fly Breeze 3x5 Foot India Flag - Vivid C...
# 5   DANF India Flag 3x5 Ft Thick Polyester, Fade R...
# 6   India Flag,3 x 5 Foot Fly Breeze Flag 100 D Po...
# 7   DMSE India Indian National Flag 2X3 Ft Foot 10...
# 8   India Flag Indian Small Stick Mini Hand Held F...
# 9   Double Sided India Flag 3x5ft Heavy Duty Delux...
# 10  TSMD India Stick Flag Indian Small Mini Hand H...
# 11  25Pack Small India Flag Handheld Mini Indian F...
# 12  50 Pack India Hand Held Mini Stick Flags, Indi...
# 13  India Indian Flag Banner String,Small Mini Ind...
# 14  Anley India Mini Flag 12 Pack - Hand Held Smal...
# 15  G128 India Indian Flag | 3x5 Ft | LiteWeave Pr...
# 16  FBYXWSIGN Indian Flag Wall Hanging Tapestry 60...
# 17  TSMD India Stick Flag Indian Small Mini Hand H...
# 18  25 Pack India Small Mini Flags, Hand Held Indi...
# 19  India Indian Flag WindSock 2 Pack Stripes Wind...
# 20  India Small String Flags, 50 Feet 38 Pcs India...
# 21  25 Pack Hand Held Small Mini Flag India Flag I...
# 22  Previous page of related Sponsored Products
# 23                           4.5 out of 5 stars    111 ratings
# 24                           4.7 out of 5 stars      4 ratings
# 25                           4.6 out of 5 stars     70 ratings
# 26                           4.6 out of 5 stars  3,156 ratings
# 27                           4.6 out of 5 stars    102 ratings
# 28                           4.7 out of 5 stars  1,773 ratings
# 29                           4.6 out of 5 stars    120 ratings
# 30                           4.1 out of 5 stars     33 ratings
# 31                           5.0 out of 5 stars      3 ratings
# 32                           4.7 out of 5 stars     72 ratings
# 33                           4.6 out of 5 stars  3,683 ratings
# 34                           5.0 out of 5 stars      2 ratings
# 35                           5.0 out of 5 stars     12 ratings
# 36                           4.7 out of 5 stars    174 ratings
# 37                           4.7 out of 5 stars    895 ratings
# 38                           4.6 out of 5 stars    227 ratings
# 39                           4.7 out of 5 stars    586 ratings
# 40                           4.0 out of 5 stars      8 ratings
# 41  Previous page of related Sponsored Products
# 42                           3.9 out of 5 stars     14 ratings
# 43                           4.2 out of 5 stars     80 ratings
# 44                           4.4 out of 5 stars     63 ratings
# 45                           4.6 out of 5 stars      3 ratings
# 46                           4.4 out of 5 stars    618 ratings
# 47                           5.0 out of 5 stars       1 rating
# 48                           4.3 out of 5 stars     45 ratings
# 49                           4.5 out of 5 stars     86 ratings
# 50                           4.8 out of 5 stars     11 ratings
# 51  Previous page of related Sponsored Products
# 52                           4.5 out of 5 stars     13 ratings
# 53                           4.7 out of 5 stars  3,290 ratings
# 54                           4.4 out of 5 stars     33 ratings
# 55                                Previous page
# 56                           4.3 out of 5 stars    110 ratings
# 57                           4.8 out of 5 stars      6 ratings
# 58                           4.7 out of 5 stars    210 ratings
# 59                           4.2 out of 5 stars     76 ratings
#
#                            availability
# 0
# 1                              In Stock
# 2   Only 13 left in stock - order soon.
# 3                              In Stock
# 4                              In Stock
# 5    Only 2 left in stock - order soon.
# 6    Usually ships within 1 to 2 months
# 7                              In Stock
# 8                              In Stock
# 9
# 10                             In Stock
# 11                             In Stock
# 12                             In Stock
# 13   Only 8 left in stock - order soon.
# 14                             In Stock
# 15                             In Stock
# 16  Only 19 left in stock - order soon.
# 17                             In Stock
# 18                             In Stock
# 19   Only 8 left in stock - order soon.
# 20                             In Stock
# 21                             In Stock
# 22                             In Stock
# 23                             In Stock
# 24                             In Stock
# 25                        Not Available
# 26  Only 20 left in stock - order soon.
# 27  Only 17 left in stock - order soon.
# 28                             In Stock
# 29  Only 20 left in stock - order soon.
# 30   Only 8 left in stock - order soon.
# 31  Only 14 left in stock - order soon.
# 32                             In Stock
# 33                             In Stock
# 34                             In Stock
# 35                             In Stock
# 36                             In Stock
# 37                             In Stock
# 38                        Not Available
# 39   Only 8 left in stock - order soon.
# 40  Only 12 left in stock - order soon.
# 41                             In Stock
# 42                             In Stock
# 43                             In Stock
# 44
# 45  Only 19 left in stock - order soon.
# 46                             In Stock
# 47                             In Stock
# 48  Only 17 left in stock - order soon.
# 49                             In Stock
# 50   Only 8 left in stock - order soon.
# 51                             In Stock
# 52                        Not Available
# 53  Only 18 left in stock - order soon.
# 54   Only 7 left in stock - order soon.
# 55                             In stock
# 56   Only 8 left in stock - order soon.
# 57   Only 2 left in stock - order soon.
# 58  Only 13 left in stock - order soon.
# 59                        Not Available
